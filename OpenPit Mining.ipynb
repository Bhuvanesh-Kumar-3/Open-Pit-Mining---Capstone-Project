# %%
#Importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings ("ignore")

# %% [markdown]
# # Data Cleaning

# %%
#Reading the datasets
cycle = pd.read_csv("CycleData.csv")
delay = pd.read_csv("DelayData.csv")
location = pd.read_csv("LocationData.csv")

# %%
cycle.head()
# Out:
#    ASSOCPAYLOADNOMINAL  AT Available Time (iMine)  Autonomous  \
# 0                  NaN                        737         1.0
# 1                  NaN                        527         1.0
# 2                  NaN                        496         1.0
# 3                  NaN                        714         1.0
# 4                  NaN                        512         1.0
#
#    Available SMU Time  Available Time  Completed Cycle Count  \
# 0                 737             737                      1
# 1                 527             527                      1
# 2                 292             496                      1
# 3                 420             714                      1
# 4                 300             512                      1
#
#    COMPLETEDCYCLEDURATION  Creation Mode  CT Calendar SMU Time  \
# 0                     737              0                   737
# 1                     527              0                   527
# 2                     496              0                   264
# 3                     714              0                   403
# 4                     512              0                   300
#
#    CT Calendar Time  ...  Primary Machine Name  Primary Machine Category Name  \
# 0               737  ...                DT5209                  Truck Classes
# 1               527  ...                DT5209                  Truck Classes
# 2               496  ...                DT5283                  Truck Classes
# 3               714  ...                DT5283                  Truck Classes
# 4               512  ...                DT5283                  Truck Classes
#
#   Primary Machine Class Name  Secondary Machine Name  \
# 0               CAT 793F CMD                  WL7058
# 1               CAT 793F CMD                  WL7058
# 2               CAT 793F CMD                  WL7058
# 3               CAT 793F CMD                  WL7058
# 4               CAT 793F CMD                  WL7058
#
#    Secondary Machine Category Name  Secondary Machine Class Name     Crew OID  \
# 0                   Loader Classes                        WA1200  10718152792
# 1                   Loader Classes                        WA1200  10718152792
# 2                   Loader Classes                        WA1200  10718152792
# 3                   Loader Classes                        WA1200  10718152792
# 4                   Loader Classes                        WA1200  10718152792
#
#    Job Code Description  Job Code Name  Job Type
# 0               unknown        unknown       NaN
# 1               unknown        unknown       NaN
# 2               unknown        unknown       NaN
# 3               unknown        unknown       NaN
# 4               unknown        unknown       NaN
#
# [5 rows x 93 columns]

# %%
cycle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47344 entries, 0 to 47343
# Data columns (total 93 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   ASSOCPAYLOADNOMINAL                         21992 non-null  float64
#  1   AT Available Time (iMine)                   47344 non-null  int64
#  2   Autonomous                                  44582 non-null  float64
#  3   Available SMU Time                          47344 non-null  int64
#  4   Available Time                              47344 non-null  int64
#  5   Completed Cycle Count                       47344 non-null  int64
#  6   COMPLETEDCYCLEDURATION                      47344 non-null  int64
#  7   Creation Mode                               47344 non-null  int64
#  8   CT Calendar SMU Time                        47344 non-null  int64
#  9   CT Calendar Time                            47344 non-null  int64
#  10  Cycle Duration                              47344 non-null  int64
#  11  Cycle SMU Duration                          47344 non-null  int64
#  12  Cycle Type                                  47344 non-null  object
#  13  Delay Time                                  47344 non-null  int64
#  14  Down Time                                   47344 non-null  int64
#  15  DTE Down Time Equipment                     47344 non-null  int64
#  16  Dumping Duration                            22590 non-null  float64
#  17  Dumping SMU Duration                        22590 non-null  float64
#  18  Destination Dumping Start Timestamp (GMT8)  21587 non-null  float64
#  19  Empty EFH Distance                          22590 non-null  float64
#  20  Empty EFH Length                            22590 non-null  float64
#  21  Empty Expected Travel Duration              22590 non-null  float64
#  22  Empty Fall Height                           22590 non-null  float64
#  23  Empty Plan Length                           22590 non-null  float64
#  24  Empty Rise Height                           22590 non-null  object
#  25  Empty Slope Distance                        22590 non-null  float64
#  26  Empty Slope Length                          22590 non-null  float64
#  27  Empty Target Travel Duration                22590 non-null  float64
#  28  Empty Travel Duration                       22590 non-null  float64
#  29  End Processor Name                          22541 non-null  object
#  30  Cycle End Timestamp (GMT8)                  47344 non-null  object
#  31  Estimated Fuel Used                         47344 non-null  int64
#  32  Fuel Used                                   22590 non-null  float64
#  33  Full Expected Travel Duration               22590 non-null  float64
#  34  Full Travel Duration                        22590 non-null  float64
#  35  IC                                          47344 non-null  int64
#  36  Idle Duration                               47344 non-null  int64
#  37  iMine Availability                          47344 non-null  int64
#  38  iMine Engine Hours                          47344 non-null  int64
#  39  iMine Load FCTR Truck                       22590 non-null  object
#  40  iMine Operating Hours                       47344 non-null  int64
#  41  iMine Utilisation                           47344 non-null  int64
#  42  Loading Count                               44582 non-null  float64
#  43  Loading Duration                            44582 non-null  float64
#  44  Loading Efficiency                          21992 non-null  float64
#  45  Source Loading End Timestamp (GMT8)         43233 non-null  float64
#  46  Source Loading Start Timestamp (GMT8)       43233 non-null  float64
#  47  OPERATINGBURNRATE                           47344 non-null  float64
#  48  OPERATINGTIME (CAT)                         47344 non-null  int64
#  49  OPERHOURSSECONDS                            47344 non-null  int64
#  50  Payload (kg)                                44582 non-null  float64
#  51  Payload (t)                                 44582 non-null  float64
#  52  PREVIOUSSECONDARYMACHINE                    44418 non-null  object
#  53  PREVIOUSSINKDESTINATION                     22516 non-null  object
#  54  QUEUEATSINKDURATION                         22590 non-null  float64
#  55  Queuing at Sink Duration                    22590 non-null  float64
#  56  Queuing at Source Duration                  22590 non-null  float64
#  57  Queuing Duration                            22590 non-null  float64
#  58  Source Queuing Start Timestamp (GMT8)       16038 non-null  float64
#  59  SD_SCHEDULEDDOWNTIME                        47344 non-null  int64
#  60  SDE_SCHEDULEDDOWNEQUIP                      47344 non-null  int64
#  61  Cycle Start Timestamp (GMT8)                47344 non-null  object
#  62  TC                                          47344 non-null  int64
#  63  TMPH                                        22590 non-null  float64
#  64  TOTALTIME (CAT)                             47344 non-null  int64
#  65  Travelling Empty Duration                   44582 non-null  float64
#  66  Travelling Full Duration                    44582 non-null  float64
#  67  TRUCKQUEUEATSOURCEDURATION                  21992 non-null  float64
#  68  UNSCHEDULEDDOWNCOUNT                        47344 non-null  int64
#  69  UNSCHEDULEDDOWNTIME                         47344 non-null  int64
#  70  Record Updated Timestamp (GMT8)             47344 non-null  object
#  71  WAITFORDUMPDURATION                         22590 non-null  float64
#  72  WAITFORLOADDURATION                         22590 non-null  float64
#  73  WORKINGBURNRATE                             47344 non-null  float64
#  74  WORKINGDURATION                             47344 non-null  int64
#  75  Source Location Name                        44477 non-null  object
#  76  Source Location Description                 5794 non-null   object
#  77  Source Location is Active Flag              47344 non-null  object
#  78  Source Location is Source Flag              47344 non-null  object
#  79  Destination Location Name                   22555 non-null  object
#  80  Destination Location Description            22555 non-null  object
#  81  Destination Location is Active Flag         47344 non-null  object
#  82  Destination Location is Source Flag         47344 non-null  object
#  83  Primary Machine Name                        47344 non-null  object
#  84  Primary Machine Category Name               47344 non-null  object
#  85  Primary Machine Class Name                  47344 non-null  object
#  86  Secondary Machine Name                      47344 non-null  object
#  87  Secondary Machine Category Name             47344 non-null  object
#  88  Secondary Machine Class Name                47344 non-null  object
#  89  Crew OID                                    47344 non-null  int64
#  90  Job Code Description                        47344 non-null  object
#  91  Job Code Name                               47344 non-null  object
#  92  Job Type                                    799 non-null    object
# dtypes: float64(37), int64(30), object(26)
# memory usage: 33.6+ MB

# %%
(cycle.isna().sum()/len(cycle))*100
# Out:
# ASSOCPAYLOADNOMINAL             53.548496
# AT Available Time (iMine)        0.000000
# Autonomous                       5.833897
# Available SMU Time               0.000000
# Available Time                   0.000000
#                                   ...
# Secondary Machine Class Name     0.000000
# Crew OID                         0.000000
# Job Code Description             0.000000
# Job Code Name                    0.000000
# Job Type                        98.312352
# Length: 93, dtype: float64

# %%
##Selecting the key columns
cycle_key = cycle[["Available Time", "Completed Cycle Count", "COMPLETEDCYCLEDURATION", "Cycle SMU Duration", "Cycle Type", "Delay Time", "Down Time", "DTE Down Time Equipment", "Dumping Duration", "Empty EFH Distance", "Empty Expected Travel Duration", "Empty Travel Duration", "Cycle End Timestamp (GMT8)", "Estimated Fuel Used", "Fuel Used", "Full Expected Travel Duration", "Full Travel Duration", "Idle Duration", "Loading Duration", "OPERATINGTIME (CAT)", "OPERHOURSSECONDS", "Payload (kg)", "Payload (t)", "PREVIOUSSECONDARYMACHINE", "PREVIOUSSINKDESTINATION", "Queuing at Sink Duration", "Queuing at Source Duration", "Queuing Duration", "SD_SCHEDULEDDOWNTIME", "Cycle Start Timestamp (GMT8)", "TC", "TMPH", "TOTALTIME (CAT)", "Travelling Empty Duration", "Travelling Full Duration", "UNSCHEDULEDDOWNTIME", "WAITFORDUMPDURATION", "WAITFORLOADDURATION", "WORKINGDURATION", "Source Location Name", "Source Location is Active Flag", "Destination Location Name", "Destination Location is Active Flag", "Primary Machine Name", "Primary Machine Category Name", "Primary Machine Class Name", "Secondary Machine Name", "Secondary Machine Category Name", "Secondary Machine Class Name", "Job Code Name", "Job Type"]]

# %%
cycle_key.head()
# Out:
#    Available Time  Completed Cycle Count  COMPLETEDCYCLEDURATION  \
# 0             737                      1                     737
# 1             527                      1                     527
# 2             496                      1                     496
# 3             714                      1                     714
# 4             512                      1                     512
#
#    Cycle SMU Duration  Cycle Type  Delay Time  Down Time  \
# 0                 737  TruckCycle           0          0
# 1                 527  TruckCycle           0          0
# 2                 292  TruckCycle           0          0
# 3                 420  TruckCycle           0          0
# 4                 300  TruckCycle           0          0
#
#    DTE Down Time Equipment  Dumping Duration  Empty EFH Distance  ...  \
# 0                        0              51.0          1628.71280  ...
# 1                        0              50.0           244.76375  ...
# 2                        0              51.0           255.88503  ...
# 3                        0              51.0           333.25912  ...
# 4                        0              52.0           244.76375  ...
#
#    Destination Location Name  Destination Location is Active Flag  \
# 0                      DS_C1                                    Y
# 1                      DS_C1                                    Y
# 2                      DS_C1                                    Y
# 3                      DS_C1                                    Y
# 4                      DS_C1                                    Y
#
#   Primary Machine Name  Primary Machine Category Name  \
# 0               DT5209                  Truck Classes
# 1               DT5209                  Truck Classes
# 2               DT5283                  Truck Classes
# 3               DT5283                  Truck Classes
# 4               DT5283                  Truck Classes
#
#    Primary Machine Class Name  Secondary Machine Name  \
# 0                CAT 793F CMD                  WL7058
# 1                CAT 793F CMD                  WL7058
# 2                CAT 793F CMD                  WL7058
# 3                CAT 793F CMD                  WL7058
# 4                CAT 793F CMD                  WL7058
#
#    Secondary Machine Category Name  Secondary Machine Class Name  \
# 0                   Loader Classes                        WA1200
# 1                   Loader Classes                        WA1200
# 2                   Loader Classes                        WA1200
# 3                   Loader Classes                        WA1200
# 4                   Loader Classes                        WA1200
#
#    Job Code Name  Job Type
# 0        unknown       NaN
# 1        unknown       NaN
# 2        unknown       NaN
# 3        unknown       NaN
# 4        unknown       NaN
#
# [5 rows x 51 columns]

# %%
cycle_key.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47344 entries, 0 to 47343
# Data columns (total 51 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Available Time                       47344 non-null  int64
#  1   Completed Cycle Count                47344 non-null  int64
#  2   COMPLETEDCYCLEDURATION               47344 non-null  int64
#  3   Cycle SMU Duration                   47344 non-null  int64
#  4   Cycle Type                           47344 non-null  object
#  5   Delay Time                           47344 non-null  int64
#  6   Down Time                            47344 non-null  int64
#  7   DTE Down Time Equipment              47344 non-null  int64
#  8   Dumping Duration                     22590 non-null  float64
#  9   Empty EFH Distance                   22590 non-null  float64
#  10  Empty Expected Travel Duration       22590 non-null  float64
#  11  Empty Travel Duration                22590 non-null  float64
#  12  Cycle End Timestamp (GMT8)           47344 non-null  object
#  13  Estimated Fuel Used                  47344 non-null  int64
#  14  Fuel Used                            22590 non-null  float64
#  15  Full Expected Travel Duration        22590 non-null  float64
#  16  Full Travel Duration                 22590 non-null  float64
#  17  Idle Duration                        47344 non-null  int64
#  18  Loading Duration                     44582 non-null  float64
#  19  OPERATINGTIME (CAT)                  47344 non-null  int64
#  20  OPERHOURSSECONDS                     47344 non-null  int64
#  21  Payload (kg)                         44582 non-null  float64
#  22  Payload (t)                          44582 non-null  float64
#  23  PREVIOUSSECONDARYMACHINE             44418 non-null  object
#  24  PREVIOUSSINKDESTINATION              22516 non-null  object
#  25  Queuing at Sink Duration             22590 non-null  float64
#  26  Queuing at Source Duration           22590 non-null  float64
#  27  Queuing Duration                     22590 non-null  float64
#  28  SD_SCHEDULEDDOWNTIME                 47344 non-null  int64
#  29  Cycle Start Timestamp (GMT8)         47344 non-null  object
#  30  TC                                   47344 non-null  int64
#  31  TMPH                                 22590 non-null  float64
#  32  TOTALTIME (CAT)                      47344 non-null  int64
#  33  Travelling Empty Duration            44582 non-null  float64
#  34  Travelling Full Duration             44582 non-null  float64
#  35  UNSCHEDULEDDOWNTIME                  47344 non-null  int64
#  36  WAITFORDUMPDURATION                  22590 non-null  float64
#  37  WAITFORLOADDURATION                  22590 non-null  float64
#  38  WORKINGDURATION                      47344 non-null  int64
#  39  Source Location Name                 44477 non-null  object
#  40  Source Location is Active Flag       47344 non-null  object
#  41  Destination Location Name            22555 non-null  object
#  42  Destination Location is Active Flag  47344 non-null  object
#  43  Primary Machine Name                 47344 non-null  object
#  44  Primary Machine Category Name        47344 non-null  object
#  45  Primary Machine Class Name           47344 non-null  object
#  46  Secondary Machine Name               47344 non-null  object
#  47  Secondary Machine Category Name      47344 non-null  object
#  48  Secondary Machine Class Name         47344 non-null  object
#  49  Job Code Name                        47344 non-null  object
#  50  Job Type                             799 non-null    object
# dtypes: float64(18), int64(16), object(17)
# memory usage: 18.4+ MB

# %%
#Finding Null Values
cycle_key.isna().sum().sort_values(ascending=False)
# Out:
# Job Type                               46545
# PREVIOUSSINKDESTINATION                24828
# Destination Location Name              24789
# WAITFORDUMPDURATION                    24754
# Dumping Duration                       24754
# Empty EFH Distance                     24754
# Empty Expected Travel Duration         24754
# Empty Travel Duration                  24754
# Fuel Used                              24754
# Full Expected Travel Duration          24754
# Full Travel Duration                   24754
# Queuing at Source Duration             24754
# Queuing Duration                       24754
# TMPH                                   24754
# Queuing at Sink Duration               24754
# WAITFORLOADDURATION                    24754
# PREVIOUSSECONDARYMACHINE                2926
# Source Location Name                    2867
# Payload (t)                             2762
# Travelling Empty Duration               2762
# Travelling Full Duration                2762
# Loading Duration                        2762
# Payload (kg)                            2762
# UNSCHEDULEDDOWNTIME                        0
# Primary Machine Class Name                 0
# Secondary Machine Name                     0
# Secondary Machine Category Name            0
# Secondary Machine Class Name               0
# DTE Down Time Equipment                    0
# Estimated Fuel Used                        0
# Down Time                                  0
# Delay Time                                 0
# Cycle Type                                 0
# Cycle SMU Duration                         0
# COMPLETEDCYCLEDURATION                     0
# Completed Cycle Count                      0
# Cycle End Timestamp (GMT8)                 0
# Idle Duration                              0
# Primary Machine Category Name              0
# Primary Machine Name                       0
# Destination Location is Active Flag        0
# OPERATINGTIME (CAT)                        0
# OPERHOURSSECONDS                           0
# Source Location is Active Flag             0
# Job Code Name                              0
# WORKINGDURATION                            0
# SD_SCHEDULEDDOWNTIME                       0
# Cycle Start Timestamp (GMT8)               0
# TC                                         0
# TOTALTIME (CAT)                            0
# Available Time                             0
# dtype: int64

# %% [markdown]
# # Treating Null Values

# %% [markdown]
# These columns having null values are key columns for TruckCycle 'PREVIOUSSINKDESTINATION', 'Destination Location Name', 'Fuel Used','WAITFORLOADDURATION', 'WAITFORDUMPDURATION', 'TMPH', 'Queuing Duration', 'Queuing at Source Duration', 'Full Travel Duration', 'Full Expected Travel Duration', 'Queuing at Sink Duration', 'Dumping Duration', 'Empty Travel Duration', 'Empty Expected Travel Duration', 'Empty EFH Distance'

# %% [markdown]
# These columns having null values comes AuxMobileCycle 'PREVIOUSSECONDARYMACHINE', 'Source Location Name', 'Loading Duration', 'Travelling Full Duration', 'Travelling Empty Duration', 'Payload (t)'

# %%
cycle_key[['Cycle End Timestamp in MM:SS','zero1']] = cycle_key['Cycle End Timestamp (GMT8)'].str.split('.',expand=True)

cycle_key[['Cycle Start Timestamp in MM:SS','zero2']] = cycle_key['Cycle Start Timestamp (GMT8)'].str.split('.',expand=True)

# %%
cycle_key.drop(columns=['Cycle End Timestamp (GMT8)', 'Cycle Start Timestamp (GMT8)', 'zero1', 'zero2'], inplace=True)

# %%
cycle_key
# Out:
#        Available Time  Completed Cycle Count  COMPLETEDCYCLEDURATION  \
# 0                 737                      1                     737
# 1                 527                      1                     527
# 2                 496                      1                     496
# 3                 714                      1                     714
# 4                 512                      1                     512
# ...               ...                    ...                     ...
# 47339            1641                      1                    1641
# 47340            1627                      1                    1627
# 47341            1288                      1                    1288
# 47342            1533                      1                    1533
# 47343            2036                      1                    2036
#
#        Cycle SMU Duration  Cycle Type  Delay Time  Down Time  \
# 0                     737  TruckCycle           0          0
# 1                     527  TruckCycle           0          0
# 2                     292  TruckCycle           0          0
# 3                     420  TruckCycle           0          0
# 4                     300  TruckCycle           0          0
# ...                   ...         ...         ...        ...
# 47339                   0  TruckCycle           0          0
# 47340                1320  TruckCycle           0          0
# 47341                1288  TruckCycle           0          0
# 47342                1532  TruckCycle           0          0
# 47343                2036  TruckCycle           0          0
#
#        DTE Down Time Equipment  Dumping Duration  Empty EFH Distance  ...  \
# 0                            0              51.0          1628.71280  ...
# 1                            0              50.0           244.76375  ...
# 2                            0              51.0           255.88503  ...
# 3                            0              51.0           333.25912  ...
# 4                            0              52.0           244.76375  ...
# ...                        ...               ...                 ...  ...
# 47339                        0              35.0          1570.26780  ...
# 47340                        0              36.0          4325.43700  ...
# 47341                        0              36.0          4344.94800  ...
# 47342                        0              35.0          6527.90700  ...
# 47343                        0              35.0          5975.76560  ...
#
#        Primary Machine Name  Primary Machine Category Name  \
# 0                    DT5209                  Truck Classes
# 1                    DT5209                  Truck Classes
# 2                    DT5283                  Truck Classes
# 3                    DT5283                  Truck Classes
# 4                    DT5283                  Truck Classes
# ...                     ...                            ...
# 47339                DT5221                  Truck Classes
# 47340                DT5275                  Truck Classes
# 47341                DT5281                  Truck Classes
# 47342                DT5305                  Truck Classes
# 47343                DT5213                  Truck Classes
#
#        Primary Machine Class Name  Secondary Machine Name  \
# 0                    CAT 793F CMD                  WL7058
# 1                    CAT 793F CMD                  WL7058
# 2                    CAT 793F CMD                  WL7058
# 3                    CAT 793F CMD                  WL7058
# 4                    CAT 793F CMD                  WL7058
# ...                           ...                     ...
# 47339                CAT 793F CMD                  EX7026
# 47340                CAT 793F CMD                  EX7026
# 47341                CAT 793F CMD                  EX7026
# 47342                CAT 793F CMD                  EX7026
# 47343                CAT 793F CMD                  EX7026
#
#        Secondary Machine Category Name  Secondary Machine Class Name  \
# 0                       Loader Classes                        WA1200
# 1                       Loader Classes                        WA1200
# 2                       Loader Classes                        WA1200
# 3                       Loader Classes                        WA1200
# 4                       Loader Classes                        WA1200
# ...                                ...                           ...
# 47339                   Shovel Classes                     LBH R9400
# 47340                   Shovel Classes                     LBH R9400
# 47341                   Shovel Classes                     LBH R9400
# 47342                   Shovel Classes                     LBH R9400
# 47343                   Shovel Classes                     LBH R9400
#
#        Job Code Name  Job Type  Cycle End Timestamp in MM:SS  \
# 0            unknown       NaN           2020-07-20 02:15:42
# 1            unknown       NaN           2020-07-20 04:58:40
# 2            unknown       NaN           2020-07-20 05:28:17
# 3            unknown       NaN           2020-07-20 03:21:49
# 4            unknown       NaN           2020-07-20 05:02:32
# ...              ...       ...                           ...
# 47339        unknown       NaN           2020-07-23 19:58:44
# 47340        unknown       NaN           2020-07-23 18:38:15
# 47341        unknown       NaN           2020-07-23 18:42:00
# 47342        unknown       NaN           2020-07-23 18:53:47
# 47343        unknown       NaN           2020-07-23 18:33:56
#
#        Cycle Start Timestamp in MM:SS
# 0                 2020-07-20 02:03:25
# 1                 2020-07-20 04:49:53
# 2                 2020-07-20 05:20:01
# 3                 2020-07-20 03:09:55
# 4                 2020-07-20 04:54:00
# ...                               ...
# 47339             2020-07-23 19:31:23
# 47340             2020-07-23 18:11:08
# 47341             2020-07-23 18:20:32
# 47342             2020-07-23 18:28:14
# 47343             2020-07-23 18:00:00
#
# [47344 rows x 51 columns]

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ### Categorical Columns

# %%
cycle_cat = cycle_key.select_dtypes(include='object').columns

# %%
cycle_cat
# Out:
# Index(['Cycle Type', 'PREVIOUSSECONDARYMACHINE', 'PREVIOUSSINKDESTINATION',
#        'Source Location Name', 'Source Location is Active Flag',
#        'Destination Location Name', 'Destination Location is Active Flag',
#        'Primary Machine Name', 'Primary Machine Category Name',
#        'Primary Machine Class Name', 'Secondary Machine Name',
#        'Secondary Machine Category Name', 'Secondary Machine Class Name',
#        'Job Code Name', 'Job Type', 'Cycle End Timestamp in MM:SS',
#        'Cycle Start Timestamp in MM:SS'],
#       dtype='object')

# %%
for column in cycle_cat[0:15]:
    sns.countplot(x= column, data = cycle_key)
    plt.xticks(rotation=90)
    plt.title(column)
    plt.show()

# %% [markdown]
# ### Detecting Outliers For Numerical Columns

# %%
cycle_num = cycle_key.select_dtypes(exclude='object').columns

# %%
for i in cycle_num[1:]:
    plt.figure(figsize=(15,4))
    sns.boxplot(cycle_key[i])
    plt.show()

# %%
#Replacing 'Completed Cycle Count' by 'Yes' or 'No' Attributes
cycle_key["Completed Cycle Count"] = cycle_key[["Completed Cycle Count"]].apply(lambda x: x.map({0:'No', 1:'Yes'}))

# %% [markdown]
# ### Extracting Movement Data from Cycle Data

# %%
##Extracting only truck cycle
movement = cycle_key[cycle_key["Cycle Type"]=="TruckCycle"][["Primary Machine Name", "Source Location Name", "Destination Location Name", "Payload (kg)", "Cycle Start Timestamp in MM:SS", "Cycle End Timestamp in MM:SS", "Completed Cycle Count", "COMPLETEDCYCLEDURATION"]]

# %%
movement.tail(10)
# Out:
#       Primary Machine Name Source Location Name Destination Location Name  \
# 47334               DT5209              DS_W55D                    DS_PC3
# 47335               DT5405              DS_W55D                    DS_PC3
# 47336               DT5273              DS_W55D                    DS_PC3
# 47337               DT5271              DS_W55D                    DS_PC3
# 47338               DT5223              DS_W55D                    DS_PC3
# 47339               DT5221              DS_W55D                    DS_PC3
# 47340               DT5275              DS_W55D                    DS_PC3
# 47341               DT5281              DS_W55D                    DS_PC3
# 47342               DT5305              DS_W55D                    DS_PC3
# 47343               DT5213              DS_W55D                    DS_PC3
#
#        Payload (kg) Cycle Start Timestamp in MM:SS  \
# 47334      234100.0            2020-07-23 19:05:02
# 47335      261000.0            2020-07-23 19:20:17
# 47336      255400.0            2020-07-23 19:27:53
# 47337      246700.0            2020-07-23 19:00:00
# 47338      241300.0            2020-07-23 19:15:28
# 47339      245100.0            2020-07-23 19:31:23
# 47340      241200.0            2020-07-23 18:11:08
# 47341      236300.0            2020-07-23 18:20:32
# 47342      240200.0            2020-07-23 18:28:14
# 47343      235900.0            2020-07-23 18:00:00
#
#       Cycle End Timestamp in MM:SS Completed Cycle Count  \
# 47334          2020-07-23 19:26:41                   Yes
# 47335          2020-07-23 19:43:47                   Yes
# 47336          2020-07-23 19:53:10                   Yes
# 47337          2020-07-23 19:24:21                   Yes
# 47338          2020-07-23 19:33:23                   Yes
# 47339          2020-07-23 19:58:44                   Yes
# 47340          2020-07-23 18:38:15                   Yes
# 47341          2020-07-23 18:42:00                   Yes
# 47342          2020-07-23 18:53:47                   Yes
# 47343          2020-07-23 18:33:56                   Yes
#
#        COMPLETEDCYCLEDURATION
# 47334                    1299
# 47335                    1410
# 47336                    1517
# 47337                    1461
# 47338                    1075
# 47339                    1641
# 47340                    1627
# 47341                    1288
# 47342                    1533
# 47343                    2036

# %%
movement.reset_index(inplace=True, drop=True)

# %%
movement
# Out:
#       Primary Machine Name Source Location Name Destination Location Name  \
# 0                   DT5209        DS_OB18_B_PAD                     DS_C1
# 1                   DT5209        DS_OB18_B_PAD                     DS_C1
# 2                   DT5283        DS_OB18_B_PAD                     DS_C1
# 3                   DT5283        DS_OB18_B_PAD                     DS_C1
# 4                   DT5283        DS_OB18_B_PAD                     DS_C1
# ...                    ...                  ...                       ...
# 22585               DT5221              DS_W55D                    DS_PC3
# 22586               DT5275              DS_W55D                    DS_PC3
# 22587               DT5281              DS_W55D                    DS_PC3
# 22588               DT5305              DS_W55D                    DS_PC3
# 22589               DT5213              DS_W55D                    DS_PC3
#
#        Payload (kg) Cycle Start Timestamp in MM:SS  \
# 0          260300.0            2020-07-20 02:03:25
# 1          224400.0            2020-07-20 04:49:53
# 2          232800.0            2020-07-20 05:20:01
# 3          238100.0            2020-07-20 03:09:55
# 4          228800.0            2020-07-20 04:54:00
# ...             ...                            ...
# 22585      245100.0            2020-07-23 19:31:23
# 22586      241200.0            2020-07-23 18:11:08
# 22587      236300.0            2020-07-23 18:20:32
# 22588      240200.0            2020-07-23 18:28:14
# 22589      235900.0            2020-07-23 18:00:00
#
#       Cycle End Timestamp in MM:SS Completed Cycle Count  \
# 0              2020-07-20 02:15:42                   Yes
# 1              2020-07-20 04:58:40                   Yes
# 2              2020-07-20 05:28:17                   Yes
# 3              2020-07-20 03:21:49                   Yes
# 4              2020-07-20 05:02:32                   Yes
# ...                            ...                   ...
# 22585          2020-07-23 19:58:44                   Yes
# 22586          2020-07-23 18:38:15                   Yes
# 22587          2020-07-23 18:42:00                   Yes
# 22588          2020-07-23 18:53:47                   Yes
# 22589          2020-07-23 18:33:56                   Yes
#
#        COMPLETEDCYCLEDURATION
# 0                         737
# 1                         527
# 2                         496
# 3                         714
# 4                         512
# ...                       ...
# 22585                    1641
# 22586                    1627
# 22587                    1288
# 22588                    1533
# 22589                    2036
#
# [22590 rows x 8 columns]

# %%
movement[movement["Completed Cycle Count"]=="No"].head()
# Out:
#     Primary Machine Name Source Location Name Destination Location Name  \
# 75                DT5283              DS_W55D                    DS_PC3
# 76                DT5225              DS_W55D                    DS_PC3
# 77                DT5213              DS_W55D                    DS_PC3
# 122               DT5215            DS_W55B_2                    DS_PC3
# 143               DT5171            DS_W55B_2                    DS_PC3
#
#      Payload (kg) Cycle Start Timestamp in MM:SS Cycle End Timestamp in MM:SS  \
# 75            0.0            2020-07-23 17:59:20          2020-07-23 18:00:00
# 76            0.0            2020-07-23 17:53:31          2020-07-23 18:00:00
# 77            0.0            2020-07-23 17:58:50          2020-07-23 18:00:00
# 122           0.0            2020-07-27 17:31:01          2020-07-27 18:00:00
# 143           0.0            2020-07-27 17:38:30          2020-07-27 18:00:00
#
#     Completed Cycle Count  COMPLETEDCYCLEDURATION
# 75                     No                       0
# 76                     No                       0
# 77                     No                       0
# 122                    No                       0
# 143                    No                       0

# %%
movement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22590 entries, 0 to 22589
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Primary Machine Name            22590 non-null  object
#  1   Source Location Name            22563 non-null  object
#  2   Destination Location Name       22555 non-null  object
#  3   Payload (kg)                    22590 non-null  float64
#  4   Cycle Start Timestamp in MM:SS  22590 non-null  object
#  5   Cycle End Timestamp in MM:SS    22590 non-null  object
#  6   Completed Cycle Count           22590 non-null  object
#  7   COMPLETEDCYCLEDURATION          22590 non-null  int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.4+ MB

# %%
movement.shape
# Out:
# (22590, 8)

# %%
#Inserting Movement ID Column
movement.insert(6,"Movement_Id",pd.Series(np.arange(1,22591)))

# %%
movement.head()
# Out:
#   Primary Machine Name Source Location Name Destination Location Name  \
# 0               DT5209        DS_OB18_B_PAD                     DS_C1
# 1               DT5209        DS_OB18_B_PAD                     DS_C1
# 2               DT5283        DS_OB18_B_PAD                     DS_C1
# 3               DT5283        DS_OB18_B_PAD                     DS_C1
# 4               DT5283        DS_OB18_B_PAD                     DS_C1
#
#    Payload (kg) Cycle Start Timestamp in MM:SS Cycle End Timestamp in MM:SS  \
# 0      260300.0            2020-07-20 02:03:25          2020-07-20 02:15:42
# 1      224400.0            2020-07-20 04:49:53          2020-07-20 04:58:40
# 2      232800.0            2020-07-20 05:20:01          2020-07-20 05:28:17
# 3      238100.0            2020-07-20 03:09:55          2020-07-20 03:21:49
# 4      228800.0            2020-07-20 04:54:00          2020-07-20 05:02:32
#
#    Movement_Id Completed Cycle Count  COMPLETEDCYCLEDURATION
# 0            1                   Yes                     737
# 1            2                   Yes                     527
# 2            3                   Yes                     496
# 3            4                   Yes                     714
# 4            5                   Yes                     512

# %% [markdown]
# ## Delay Table

# %%
#Selecting Key Columns
delay_key = delay[["Delay OID", "Description", "Engine Stopped Flag", "Field Notification Required Flag", "Production Reporting Only Flag", "Delay Class Name", "Delay Class Category Name", "Target Machine Name", "Target Machine Class Name", "Target Machine Class Description", "Target Machine Class Category Name", "Delay Start Timestamp (GMT8)", "Delay Finish Timestamp (GMT8)"]]

# %%
delay_key.head()
# Out:
#      Delay OID                                        Description  \
# 0  10721642969  MACHINE GEN Started a delay: 2110_Operator_Hot...
# 1  10721643044                                               6026
# 2  10721643462            - [STOP_MACHINE : [PRIMARY_POWERTRAIN]]
# 3  10721643635   - [STOP_MACHINE : [PRIMARY_POWERTRAIN]] acces...
# 4  10721645207                                               5271
#
#   Engine Stopped Flag Field Notification Required Flag  \
# 0                   N                                N
# 1                   N                                Y
# 2                   N                                N
# 3                   N                                Y
# 4                   N                                Y
#
#   Production Reporting Only Flag                Delay Class Name  \
# 0                              Y          2110_Operator_Hot_Seat
# 1                              Y             4070_Wait_on_Access
# 2                              Y               8200 Health Event
# 3                              Y  4170_Operator_Equipment_Checks
# 4                              N     7410_Behind_Delayed_Machine
#
#     Delay Class Category Name Target Machine Name Target Machine Class Name  \
# 0      Scheduled Process Down              WL7030                      994H
# 1    Unscheduled Process Down              DT5266              CAT 793F CMD
# 2  Unscheduled Equipment Down              DT5271              CAT 793F CMD
# 3    Unscheduled Process Down              DT5271              CAT 793F CMD
# 4    Unscheduled Process Down              DT5212              CAT 793F CMD
#
#             Target Machine Class Description  \
# 0                               Wheel Loader
# 1  Caterpillar 793 F Autonomous Mining Truck
# 2  Caterpillar 793 F Autonomous Mining Truck
# 3  Caterpillar 793 F Autonomous Mining Truck
# 4  Caterpillar 793 F Autonomous Mining Truck
#
#   Target Machine Class Category Name Delay Start Timestamp (GMT8)  \
# 0                     Loader Classes          2020-07-26 02:04:59
# 1                      Truck Classes          2020-07-26 01:59:06
# 2                      Truck Classes          2020-07-26 02:06:13
# 3                      Truck Classes          2020-07-26 02:06:25
# 4                      Truck Classes          2020-07-26 02:09:44
#
#   Delay Finish Timestamp (GMT8)
# 0           2020-07-26 02:08:41
# 1           2020-07-26 02:05:54
# 2           2020-07-26 02:06:24
# 3           2020-07-26 02:23:48
# 4           2020-07-26 02:15:00

# %%
delay_key.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8782 entries, 0 to 8781
# Data columns (total 13 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Delay OID                           8782 non-null   int64
#  1   Description                         6701 non-null   object
#  2   Engine Stopped Flag                 8782 non-null   object
#  3   Field Notification Required Flag    8782 non-null   object
#  4   Production Reporting Only Flag      8782 non-null   object
#  5   Delay Class Name                    8782 non-null   object
#  6   Delay Class Category Name           8782 non-null   object
#  7   Target Machine Name                 8782 non-null   object
#  8   Target Machine Class Name           8782 non-null   object
#  9   Target Machine Class Description    8782 non-null   object
#  10  Target Machine Class Category Name  8782 non-null   object
#  11  Delay Start Timestamp (GMT8)        8782 non-null   object
#  12  Delay Finish Timestamp (GMT8)       8782 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 892.0+ KB

# %%
#Coverting Delay Start and Finish into Timestamp Datatypes
delay_key['Delay Start Timestamp (GMT8)'] = delay_key['Delay Start Timestamp (GMT8)'].astype('datetime64')

delay_key['Delay Finish Timestamp (GMT8)'] = delay_key['Delay Finish Timestamp (GMT8)'].astype('datetime64')

# %%
#Inserting "Delay Finish - Start" Column to know the Measurement
delay_key["Delay Finish - Start"] = (delay_key['Delay Finish Timestamp (GMT8)'] - delay_key['Delay Start Timestamp (GMT8)']).astype('timedelta64[s]')

delay_key["Delay Finish - Start"] = delay_key["Delay Finish - Start"].astype('int64')

# %%
delay_key.head()
# Out:
#      Delay OID                                        Description  \
# 0  10721642969  MACHINE GEN Started a delay: 2110_Operator_Hot...
# 1  10721643044                                               6026
# 2  10721643462            - [STOP_MACHINE : [PRIMARY_POWERTRAIN]]
# 3  10721643635   - [STOP_MACHINE : [PRIMARY_POWERTRAIN]] acces...
# 4  10721645207                                               5271
#
#   Engine Stopped Flag Field Notification Required Flag  \
# 0                   N                                N
# 1                   N                                Y
# 2                   N                                N
# 3                   N                                Y
# 4                   N                                Y
#
#   Production Reporting Only Flag                Delay Class Name  \
# 0                              Y          2110_Operator_Hot_Seat
# 1                              Y             4070_Wait_on_Access
# 2                              Y               8200 Health Event
# 3                              Y  4170_Operator_Equipment_Checks
# 4                              N     7410_Behind_Delayed_Machine
#
#     Delay Class Category Name Target Machine Name Target Machine Class Name  \
# 0      Scheduled Process Down              WL7030                      994H
# 1    Unscheduled Process Down              DT5266              CAT 793F CMD
# 2  Unscheduled Equipment Down              DT5271              CAT 793F CMD
# 3    Unscheduled Process Down              DT5271              CAT 793F CMD
# 4    Unscheduled Process Down              DT5212              CAT 793F CMD
#
#             Target Machine Class Description  \
# 0                               Wheel Loader
# 1  Caterpillar 793 F Autonomous Mining Truck
# 2  Caterpillar 793 F Autonomous Mining Truck
# 3  Caterpillar 793 F Autonomous Mining Truck
# 4  Caterpillar 793 F Autonomous Mining Truck
#
#   Target Machine Class Category Name Delay Start Timestamp (GMT8)  \
# 0                     Loader Classes          2020-07-26 02:04:59
# 1                      Truck Classes          2020-07-26 01:59:06
# 2                      Truck Classes          2020-07-26 02:06:13
# 3                      Truck Classes          2020-07-26 02:06:25
# 4                      Truck Classes          2020-07-26 02:09:44
#
#   Delay Finish Timestamp (GMT8)  Delay Finish - Start
# 0           2020-07-26 02:08:41                   222
# 1           2020-07-26 02:05:54                   408
# 2           2020-07-26 02:06:24                    11
# 3           2020-07-26 02:23:48                  1043
# 4           2020-07-26 02:15:00                   316

# %%
delay_key[delay_key['Target Machine Name'] == 'DT5216'].groupby(by=["Target Machine Name"]).sum()
# Out:
#                         Delay OID  Delay Finish - Start
# Target Machine Name
# DT5216               954130939886                 71340

# %% [markdown]
# ## Location Table

# %%
location
# Out:
#     Location_Id               Name   Latitude    Longitude
# 0             1            DS_H1C1  23.370670  4067.363348
# 1             2         DS_JB_Fill  23.378029  3883.118054
# 2             3       DS_OB18_18EP  23.321309  4202.132688
# 3             4         DS_OB31B_3  23.317018  4203.555368
# 4             5       DS_STH_PIT_2  23.393871  3883.003552
# 5             6            DS_W1A2  23.164861  4202.946825
# 6             7          DS_W2C2_1  23.374642  4043.319503
# 7             8            DS_W55B  23.378768  4205.860720
# 8             9          DS_W55B_2  23.371916  4056.194529
# 9            10            DS_W55D  23.371724  4045.024300
# 10           11    DS_OB31_NORTH_2  23.317247  4203.552994
# 11           12    DS_OB31_NORTH_2 -23.306816   120.092117
# 12           13    DS_OB31_NORTH_3 -23.305212   120.095535
# 13           14             DS_PC1 -23.380738   120.107631
# 14           15             DS_PC3 -23.383169   120.181625
# 15           16      DS_SJS_AV05_1 -23.368467   120.089446
# 16           17         DS_W3_AX11 -23.368104   120.106472
# 17           18       DS_W5_BD08_2 -23.382932   120.185689
# 18           19         DS_W5_BI12 -23.376023   120.172029
# 19           20         DS_W5_BN10 -23.382040   120.190122
# 20           21       DS_W5_BN10_2 -23.381506   120.191014
# 21           22           DS_AU_12 -23.377712   120.100733
# 22           23  DS_OB18_BLACKWOOD -23.335497   120.042332
# 23           24     DS_PC3_WASTE_3 -23.380471   120.173828
# 24           25          DS_OB18_A -23.338263   120.043252
# 25           26       DS_OB18_FP02 -23.334046   120.041567
# 26           27         DS_W2_AV08 -23.368831   120.105023
# 27           28              DS_C1 -23.332080   120.051541
# 28           29         0.30617088 -23.385437   120.096903
# 29           30                1.0 -23.374263   120.135284
# 30           31        DS_W3_ANZAC -23.368739   120.111023

# %%
location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Location_Id  31 non-null     int64
#  1   Name         31 non-null     object
#  2   Latitude     31 non-null     float64
#  3   Longitude    31 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
location.Name.value_counts()
# Out:
# DS_OB31_NORTH_2      2
# DS_W55B_2            1
# DS_W3_AX11           1
# DS_OB18_FP02         1
# DS_W2C2_1            1
# DS_C1                1
# DS_W5_BN10           1
# DS_W5_BI12           1
# DS_OB31B_3           1
# DS_OB31_NORTH_3      1
# DS_SJS_AV05_1        1
# DS_OB18_BLACKWOOD    1
# DS_AU_12             1
# DS_PC3_WASTE_3       1
# DS_W55B              1
# DS_OB18_A            1
# DS_STH_PIT_2         1
# DS_H1C1              1
# 1.0                  1
# DS_W1A2              1
# DS_W5_BN10_2         1
# DS_PC3               1
# DS_W2_AV08           1
# DS_W3_ANZAC          1
# DS_OB18_18EP         1
# DS_PC1               1
# DS_W55D              1
# DS_JB_Fill           1
# 0.30617088           1
# DS_W5_BD08_2         1
# Name: Name, dtype: int64

# %%
#Removing the Rows which does not create any impact on analysis
location = location.drop(index=[10, 28, 29])

# %%
location.reset_index(inplace=True, drop=True)

# %%
location
# Out:
#     Location_Id               Name   Latitude    Longitude
# 0             1            DS_H1C1  23.370670  4067.363348
# 1             2         DS_JB_Fill  23.378029  3883.118054
# 2             3       DS_OB18_18EP  23.321309  4202.132688
# 3             4         DS_OB31B_3  23.317018  4203.555368
# 4             5       DS_STH_PIT_2  23.393871  3883.003552
# 5             6            DS_W1A2  23.164861  4202.946825
# 6             7          DS_W2C2_1  23.374642  4043.319503
# 7             8            DS_W55B  23.378768  4205.860720
# 8             9          DS_W55B_2  23.371916  4056.194529
# 9            10            DS_W55D  23.371724  4045.024300
# 10           12    DS_OB31_NORTH_2 -23.306816   120.092117
# 11           13    DS_OB31_NORTH_3 -23.305212   120.095535
# 12           14             DS_PC1 -23.380738   120.107631
# 13           15             DS_PC3 -23.383169   120.181625
# 14           16      DS_SJS_AV05_1 -23.368467   120.089446
# 15           17         DS_W3_AX11 -23.368104   120.106472
# 16           18       DS_W5_BD08_2 -23.382932   120.185689
# 17           19         DS_W5_BI12 -23.376023   120.172029
# 18           20         DS_W5_BN10 -23.382040   120.190122
# 19           21       DS_W5_BN10_2 -23.381506   120.191014
# 20           22           DS_AU_12 -23.377712   120.100733
# 21           23  DS_OB18_BLACKWOOD -23.335497   120.042332
# 22           24     DS_PC3_WASTE_3 -23.380471   120.173828
# 23           25          DS_OB18_A -23.338263   120.043252
# 24           26       DS_OB18_FP02 -23.334046   120.041567
# 25           27         DS_W2_AV08 -23.368831   120.105023
# 26           28              DS_C1 -23.332080   120.051541
# 27           31        DS_W3_ANZAC -23.368739   120.111023

# %% [markdown]
# ## Creating Two separate Table Based on Location Type

# %%
#Destination Location
Dest_Location = location[location.Latitude < 0]

# %%
Dest_Location.reset_index(inplace=True, drop=True)

# %%
Dest_Location.columns = ['Dest_Location_Id', 'Dest_Name', 'Dest_Latitude', 'Dest_Longitude']

# %%
#Source Location
Source_Location = location[location.Latitude > 0]

# %%
Source_Location.columns = ['Source_Location_Id', 'Source_Name', 'Source_Latitude', 'Source_Longitude']

# %%
Source_Location
# Out:
#    Source_Location_Id   Source_Name  Source_Latitude  Source_Longitude
# 0                   1       DS_H1C1        23.370670       4067.363348
# 1                   2    DS_JB_Fill        23.378029       3883.118054
# 2                   3  DS_OB18_18EP        23.321309       4202.132688
# 3                   4    DS_OB31B_3        23.317018       4203.555368
# 4                   5  DS_STH_PIT_2        23.393871       3883.003552
# 5                   6       DS_W1A2        23.164861       4202.946825
# 6                   7     DS_W2C2_1        23.374642       4043.319503
# 7                   8       DS_W55B        23.378768       4205.860720
# 8                   9     DS_W55B_2        23.371916       4056.194529
# 9                  10       DS_W55D        23.371724       4045.024300

# %% [markdown]
# ### Merging the Location Type Tables in Movement Data

# %%
movement_key = movement.merge(Source_Location, how='left', left_on=["Source Location Name"], right_on=["Source_Name"])

# %%
movement_key = movement_key.merge(Dest_Location, how='left', left_on=["Destination Location Name"], right_on=["Dest_Name"])

# %%
#Dropping Unnecessary Columns
movement_key.drop(columns=['Source_Name','Source_Location_Id', 'Dest_Name', 'Dest_Location_Id'], inplace=True)

# %%
movement_key.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22590 entries, 0 to 22589
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Primary Machine Name            22590 non-null  object
#  1   Source Location Name            22563 non-null  object
#  2   Destination Location Name       22555 non-null  object
#  3   Payload (kg)                    22590 non-null  float64
#  4   Cycle Start Timestamp in MM:SS  22590 non-null  object
#  5   Cycle End Timestamp in MM:SS    22590 non-null  object
#  6   Movement_Id                     22590 non-null  int32
#  7   Completed Cycle Count           22590 non-null  object
#  8   COMPLETEDCYCLEDURATION          22590 non-null  int64
#  9   Source_Latitude                 19828 non-null  float64
#  10  Source_Longitude                19828 non-null  float64
#  11  Dest_Latitude                   16722 non-null  float64
#  12  Dest_Longitude                  16722 non-null  float64
# dtypes: float64(5), int32(1), int64(1), object(6)
# memory usage: 2.3+ MB

# %%
movement_key
# Out:
#       Primary Machine Name Source Location Name Destination Location Name  \
# 0                   DT5209        DS_OB18_B_PAD                     DS_C1
# 1                   DT5209        DS_OB18_B_PAD                     DS_C1
# 2                   DT5283        DS_OB18_B_PAD                     DS_C1
# 3                   DT5283        DS_OB18_B_PAD                     DS_C1
# 4                   DT5283        DS_OB18_B_PAD                     DS_C1
# ...                    ...                  ...                       ...
# 22585               DT5221              DS_W55D                    DS_PC3
# 22586               DT5275              DS_W55D                    DS_PC3
# 22587               DT5281              DS_W55D                    DS_PC3
# 22588               DT5305              DS_W55D                    DS_PC3
# 22589               DT5213              DS_W55D                    DS_PC3
#
#        Payload (kg) Cycle Start Timestamp in MM:SS  \
# 0          260300.0            2020-07-20 02:03:25
# 1          224400.0            2020-07-20 04:49:53
# 2          232800.0            2020-07-20 05:20:01
# 3          238100.0            2020-07-20 03:09:55
# 4          228800.0            2020-07-20 04:54:00
# ...             ...                            ...
# 22585      245100.0            2020-07-23 19:31:23
# 22586      241200.0            2020-07-23 18:11:08
# 22587      236300.0            2020-07-23 18:20:32
# 22588      240200.0            2020-07-23 18:28:14
# 22589      235900.0            2020-07-23 18:00:00
#
#       Cycle End Timestamp in MM:SS  Movement_Id Completed Cycle Count  \
# 0              2020-07-20 02:15:42            1                   Yes
# 1              2020-07-20 04:58:40            2                   Yes
# 2              2020-07-20 05:28:17            3                   Yes
# 3              2020-07-20 03:21:49            4                   Yes
# 4              2020-07-20 05:02:32            5                   Yes
# ...                            ...          ...                   ...
# 22585          2020-07-23 19:58:44        22586                   Yes
# 22586          2020-07-23 18:38:15        22587                   Yes
# 22587          2020-07-23 18:42:00        22588                   Yes
# 22588          2020-07-23 18:53:47        22589                   Yes
# 22589          2020-07-23 18:33:56        22590                   Yes
#
#        COMPLETEDCYCLEDURATION  Source_Latitude  Source_Longitude  \
# 0                         737              NaN               NaN
# 1                         527              NaN               NaN
# 2                         496              NaN               NaN
# 3                         714              NaN               NaN
# 4                         512              NaN               NaN
# ...                       ...              ...               ...
# 22585                    1641        23.371724         4045.0243
# 22586                    1627        23.371724         4045.0243
# 22587                    1288        23.371724         4045.0243
# 22588                    1533        23.371724         4045.0243
# 22589                    2036        23.371724         4045.0243
#
#        Dest_Latitude  Dest_Longitude
# 0         -23.332080      120.051541
# 1         -23.332080      120.051541
# 2         -23.332080      120.051541
# 3         -23.332080      120.051541
# 4         -23.332080      120.051541
# ...              ...             ...
# 22585     -23.383169      120.181625
# 22586     -23.383169      120.181625
# 22587     -23.383169      120.181625
# 22588     -23.383169      120.181625
# 22589     -23.383169      120.181625
#
# [22590 rows x 13 columns]

# %% [markdown]
# #### Merging Location Type Tables in Cycle Data

# %%
cycle_key = cycle_key.merge(Source_Location, how='left', left_on=["Source Location Name"], right_on=["Source_Name"])

# %%
cycle_key = cycle_key.merge(Dest_Location, how='left', left_on=["Destination Location Name"], right_on=["Dest_Name"])

# %%
#Dropping Unnecessary Columns
cycle_key.drop(columns=['Source_Name','Source_Location_Id', 'Dest_Name', 'Dest_Location_Id'], inplace=True)

# %%
cycle_key.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47344 entries, 0 to 47343
# Data columns (total 55 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Available Time                       47344 non-null  int64
#  1   Completed Cycle Count                47344 non-null  object
#  2   COMPLETEDCYCLEDURATION               47344 non-null  int64
#  3   Cycle SMU Duration                   47344 non-null  int64
#  4   Cycle Type                           47344 non-null  object
#  5   Delay Time                           47344 non-null  int64
#  6   Down Time                            47344 non-null  int64
#  7   DTE Down Time Equipment              47344 non-null  int64
#  8   Dumping Duration                     22590 non-null  float64
#  9   Empty EFH Distance                   22590 non-null  float64
#  10  Empty Expected Travel Duration       22590 non-null  float64
#  11  Empty Travel Duration                22590 non-null  float64
#  12  Estimated Fuel Used                  47344 non-null  int64
#  13  Fuel Used                            22590 non-null  float64
#  14  Full Expected Travel Duration        22590 non-null  float64
#  15  Full Travel Duration                 22590 non-null  float64
#  16  Idle Duration                        47344 non-null  int64
#  17  Loading Duration                     44582 non-null  float64
#  18  OPERATINGTIME (CAT)                  47344 non-null  int64
#  19  OPERHOURSSECONDS                     47344 non-null  int64
#  20  Payload (kg)                         44582 non-null  float64
#  21  Payload (t)                          44582 non-null  float64
#  22  PREVIOUSSECONDARYMACHINE             44418 non-null  object
#  23  PREVIOUSSINKDESTINATION              22516 non-null  object
#  24  Queuing at Sink Duration             22590 non-null  float64
#  25  Queuing at Source Duration           22590 non-null  float64
#  26  Queuing Duration                     22590 non-null  float64
#  27  SD_SCHEDULEDDOWNTIME                 47344 non-null  int64
#  28  TC                                   47344 non-null  int64
#  29  TMPH                                 22590 non-null  float64
#  30  TOTALTIME (CAT)                      47344 non-null  int64
#  31  Travelling Empty Duration            44582 non-null  float64
#  32  Travelling Full Duration             44582 non-null  float64
#  33  UNSCHEDULEDDOWNTIME                  47344 non-null  int64
#  34  WAITFORDUMPDURATION                  22590 non-null  float64
#  35  WAITFORLOADDURATION                  22590 non-null  float64
#  36  WORKINGDURATION                      47344 non-null  int64
#  37  Source Location Name                 44477 non-null  object
#  38  Source Location is Active Flag       47344 non-null  object
#  39  Destination Location Name            22555 non-null  object
#  40  Destination Location is Active Flag  47344 non-null  object
#  41  Primary Machine Name                 47344 non-null  object
#  42  Primary Machine Category Name        47344 non-null  object
#  43  Primary Machine Class Name           47344 non-null  object
#  44  Secondary Machine Name               47344 non-null  object
#  45  Secondary Machine Category Name      47344 non-null  object
#  46  Secondary Machine Class Name         47344 non-null  object
#  47  Job Code Name                        47344 non-null  object
#  48  Job Type                             799 non-null    object
#  49  Cycle End Timestamp in MM:SS         47344 non-null  object
#  50  Cycle Start Timestamp in MM:SS       47344 non-null  object
#  51  Source_Latitude                      39000 non-null  float64
#  52  Source_Longitude                     39000 non-null  float64
#  53  Dest_Latitude                        16722 non-null  float64
#  54  Dest_Longitude                       16722 non-null  float64
# dtypes: float64(22), int64(15), object(18)
# memory usage: 20.2+ MB

# %% [markdown]
# # Inserting Cleaned Data Into MySQL Database

# %%
import sqlalchemy as sq
#import pymysql
con = sq.create_engine("mysql+pymysql://root:Bhuvanesh@localhost/OpenPit")
cycle_key.to_sql("cycle",con)
movement_key.to_sql("movement",con)
delay_key.to_sql("delay",con)
